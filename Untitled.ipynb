# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import plotly.express as px

# %%
life_expectancy = pd.read_csv('Life Expectancy Data.csv')

# %%
life_expectancy.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
life_expectancy.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
life_expectancy.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# min       0.010000                0.000000     1.000000       0.000000
# 25%       0.877500                4.685343    77.000000       0.000000
# 50%       3.755000               64.912906    92.000000      17.000000
# 75%       7.702500              441.534144    97.000000     360.250000
# max      17.870000            19479.911610    99.000000  212183.000000
#
#               BMI   under-five deaths         Polio  Total expenditure  \
# count  2904.000000         2938.000000  2919.000000         2712.00000
# mean     38.321247           42.035739    82.550188            5.93819
# std      20.044034          160.445548    23.428046            2.49832
# min       1.000000            0.000000     3.000000            0.37000
# 25%      19.300000            0.000000    78.000000            4.26000
# 50%      43.500000            4.000000    93.000000            5.75500
# 75%      56.200000           28.000000    97.000000            7.49250
# max      87.300000         2500.000000    99.000000           17.60000
#
#        Diphtheria      HIV/AIDS            GDP    Population  \
# count  2919.000000  2938.000000    2490.000000  2.286000e+03
# mean     82.324084     1.742103    7483.158469  1.275338e+07
# std      23.716912     5.077785   14270.169342  6.101210e+07
# min       2.000000     0.100000       1.681350  3.400000e+01
# 25%      78.000000     0.100000     463.935626  1.957932e+05
# 50%      93.000000     0.100000    1766.947595  1.386542e+06
# 75%      97.000000     0.800000    5910.806335  7.420359e+06
# max      99.000000    50.600000  119172.741800  1.293859e+09
#
#         thinness  1-19 years   thinness 5-9 years  \
# count            2904.000000          2904.000000
# mean                4.839704             4.870317
# std                 4.420195             4.508882
# min                 0.100000             0.100000
# 25%                 1.600000             1.500000
# 50%                 3.300000             3.300000
# 75%                 7.200000             7.200000
# max                27.700000            28.600000
#
#        Income composition of resources    Schooling
# count                      2771.000000  2775.000000
# mean                          0.627551    11.992793
# std                           0.210904     3.358920
# min                           0.000000     0.000000
# 25%                           0.493000    10.100000
# 50%                           0.677000    12.300000
# 75%                           0.779000    14.300000
# max                           0.948000    20.700000

# %%
nan_analysis = pd.DataFrame()

# %%
for Year_ in life_expectancy.loc[ : , "Year" ].drop_duplicates():
    countrydf = life_expectancy.loc[ life_expectancy['Year'] == Year_ , : ]    
    for column_ in countrydf.columns:        
        percentage =  np.sum(pd.isna( countrydf.loc[ : , column_ ]  )) / countrydf.shape[0]
        dfrow = pd.DataFrame({
            'Year': [ Year_ ]
            , 'column' : [ column_ ]
            , 'percentage.of.nans' : [ percentage ]
        })
        nan_analysis = pd.concat([nan_analysis, dfrow])

# %%
nan_analysis
# Out:
#     Year                           column  percentage.of.nans
# 0   2015                          Country            0.000000
# 0   2015                             Year            0.000000
# 0   2015                           Status            0.000000
# 0   2015                 Life expectancy             0.000000
# 0   2015                  Adult Mortality            0.000000
# ..   ...                              ...                 ...
# 0   2000                       Population            0.218579
# 0   2000             thinness  1-19 years            0.010929
# 0   2000               thinness 5-9 years            0.010929
# 0   2000  Income composition of resources            0.054645
# 0   2000                        Schooling            0.054645
#
# [352 rows x 3 columns]

# %% [markdown]
# ### LIMPIEZA DE VALORES NULOS

# %%
vdf1= life_expectancy

# %%
for c_ in vdf1.columns:
    print(c_)
    print(np.sum(vdf1[c_].isna()))
    print(" ")
# Out:
# Country
# 0
#
# Year
# 0
#
# Status
# 0
#
# Life expectancy
# 10
#
# Adult Mortality
# 10
#
# infant deaths
# 0
#
# Alcohol
# 194
#
# percentage expenditure
# 0
#
# Hepatitis B
# 553
#
# Measles
# 0
#
#  BMI
# 34
#
# under-five deaths
# 0
#
# Polio
# 19
#
# Total expenditure
# 226
#
# Diphtheria
# 19
#
#  HIV/AIDS
# 0
#
# GDP
# 448
#
# Population
# 652
#
#  thinness  1-19 years
# 34
#
#  thinness 5-9 years
# 34
#
# Income composition of resources
# 167
#
# Schooling
# 163

# %%
culumnas_a_limpiar= ['Life expectancy ','Adult Mortality','Alcohol','Hepatitis B',' BMI ', 'Polio','Total expenditure','Diphtheria ','GDP','Population',' thinness  1-19 years',' thinness 5-9 years','Income composition of resources','Schooling']

# %%
for d_ in vdf1[culumnas_a_limpiar]:
    mediana= vdf1[d_].median()
    vdf1[d_]=vdf1[d_].fillna(mediana)

# %% [markdown]
# ### COMPROBANDO QUE SE HA REALIZADO DE MANERA CORRECTA LA LIMPIEZA EN VDF1

# %%
for c_ in vdf1.columns:
    print(c_)
    print(np.sum(vdf1[c_].isna()))
    print(" ")
# Out:
# Country
# 0
#
# Year
# 0
#
# Status
# 0
#
# Life expectancy
# 0
#
# Adult Mortality
# 0
#
# infant deaths
# 0
#
# Alcohol
# 0
#
# percentage expenditure
# 0
#
# Hepatitis B
# 0
#
# Measles
# 0
#
#  BMI
# 0
#
# under-five deaths
# 0
#
# Polio
# 0
#
# Total expenditure
# 0
#
# Diphtheria
# 0
#
#  HIV/AIDS
# 0
#
# GDP
# 0
#
# Population
# 0
#
#  thinness  1-19 years
# 0
#
#  thinness 5-9 years
# 0
#
# Income composition of resources
# 0
#
# Schooling
# 0

# %%
vdf1
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0                62     0.01               71.279624         65.0      1154
# 1                64     0.01               73.523582         62.0       492
# 2                66     0.01               73.219243         64.0       430
# 3                69     0.01               78.184215         67.0      2787
# 4                71     0.01                7.097109         68.0      3013
# ...             ...      ...                     ...          ...       ...
# 2933             27     4.36                0.000000         68.0        31
# 2934             26     4.06                0.000000          7.0       998
# 2935             25     4.43                0.000000         73.0       304
# 2936             25     1.72                0.000000         76.0       529
# 2937             24     1.68                0.000000         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 0     ...    6.0               8.16         65.0        0.1  584.259210
# 1     ...   58.0               8.18         62.0        0.1  612.696514
# 2     ...   62.0               8.13         64.0        0.1  631.744976
# 3     ...   67.0               8.52         67.0        0.1  669.959000
# 4     ...   68.0               7.87         68.0        0.1   63.537231
# ...   ...    ...                ...          ...        ...         ...
# 2933  ...   67.0               7.13         65.0       33.6  454.366654
# 2934  ...    7.0               6.52         68.0       36.7  453.351155
# 2935  ...   73.0               6.53         71.0       39.8   57.348340
# 2936  ...   76.0               6.16         75.0       42.1  548.587312
# 2937  ...   78.0               7.10         78.0       43.5  547.358878
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 0     33736494.0                   17.2                 17.3
# 1       327582.0                   17.5                 17.5
# 2     31731688.0                   17.7                 17.7
# 3      3696958.0                   17.9                 18.0
# 4      2978599.0                   18.2                 18.2
# ...          ...                    ...                  ...
# 2933  12777511.0                    9.4                  9.4
# 2934  12633897.0                    9.8                  9.9
# 2935    125525.0                    1.2                  1.3
# 2936  12366165.0                    1.6                  1.7
# 2937  12222251.0                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2938 rows x 22 columns]

# %% [markdown]
# ## Bloxplots

# %%
plt.figure(figsize=(30,100))
plt.subplot(15,4,1)
plt.boxplot(life_expectancy["Life expectancy "].dropna(),whis=1.5)
plt.title("Life expectancy ")
# Out:
# Text(0.5, 1.0, 'Life expectancy ')

# %% [markdown]
# ## Histogramas

# %%
life_expectancy['Life expectancy '].hist( bins = 20 )
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Varianza

# %% [markdown]
# ## Correlaciones

# %%
columns_to_use = [ 'Life expectancy ', 'Adult Mortality',
       'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
       'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
       'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
       ' thinness  1-19 years', ' thinness 5-9 years',
       'Income composition of resources', 'Schooling']

# %%
le_corr = vdf1.loc[ : , columns_to_use  ].corr()
le_corr
# Out:
#                                  Life expectancy   Adult Mortality  \
# Life expectancy                          1.000000        -0.696390
# Adult Mortality                         -0.696390         1.000000
# infant deaths                           -0.196769         0.078890
# Alcohol                                  0.388918        -0.190191
# percentage expenditure                   0.381418        -0.242628
# Hepatitis B                              0.170219        -0.123287
# Measles                                 -0.157767         0.031293
#  BMI                                     0.556901        -0.379092
# under-five deaths                       -0.222738         0.094280
# Polio                                    0.458399        -0.270002
# Total expenditure                        0.208844        -0.111796
# Diphtheria                               0.472211        -0.270301
#  HIV/AIDS                               -0.556703         0.523886
# GDP                                      0.430461        -0.281434
# Population                              -0.029014        -0.005292
#  thinness  1-19 years                   -0.468002         0.296135
#  thinness 5-9 years                     -0.462473         0.301634
# Income composition of resources          0.688662        -0.436332
# Schooling                                0.713054        -0.433415
#
#                                  infant deaths   Alcohol  \
# Life expectancy                      -0.196769  0.388918
# Adult Mortality                       0.078890 -0.190191
# infant deaths                         1.000000 -0.112918
# Alcohol                              -0.112918  1.000000
# percentage expenditure               -0.085612  0.344410
# Hepatitis B                          -0.167421  0.090850
# Measles                               0.501128 -0.049752
#  BMI                                 -0.226796  0.313022
# under-five deaths                     0.996629 -0.109790
# Polio                                -0.170896  0.211744
# Total expenditure                    -0.126268  0.296153
# Diphtheria                           -0.175376  0.212388
#  HIV/AIDS                             0.025231 -0.046235
# GDP                                  -0.102829  0.313060
# Population                            0.551667 -0.026836
#  thinness  1-19 years                 0.464811 -0.413021
#  thinness 5-9 years                   0.470445 -0.402034
# Income composition of resources      -0.141571  0.418372
# Schooling                            -0.190951  0.498899
#
#                                  percentage expenditure  Hepatitis B  \
# Life expectancy                                0.381418     0.170219
# Adult Mortality                               -0.242628    -0.123287
# infant deaths                                 -0.085612    -0.167421
# Alcohol                                        0.344410     0.090850
# percentage expenditure                         1.000000     0.039528
# Hepatitis B                                    0.039528     1.000000
# Measles                                       -0.056596    -0.073021
#  BMI                                           0.227408     0.112441
# under-five deaths                             -0.087852    -0.170549
# Polio                                          0.146148     0.364890
# Total expenditure                              0.175559     0.055988
# Diphtheria                                     0.142506     0.449151
#  HIV/AIDS                                     -0.097857    -0.085497
# GDP                                            0.901819     0.076660
# Population                                    -0.016888    -0.125006
#  thinness  1-19 years                         -0.249610    -0.097576
#  thinness 5-9 years                           -0.251144    -0.100576
# Income composition of resources                0.374730     0.117652
# Schooling                                      0.386076     0.141275
#
#                                  Measles       BMI   under-five deaths   \
# Life expectancy                 -0.157767  0.556901           -0.222738
# Adult Mortality                  0.031293 -0.379092            0.094280
# infant deaths                    0.501128 -0.226796            0.996629
# Alcohol                         -0.049752  0.313022           -0.109790
# percentage expenditure          -0.056596  0.227408           -0.087852
# Hepatitis B                     -0.073021  0.112441           -0.170549
# Measles                          1.000000 -0.176069            0.507809
#  BMI                            -0.176069  1.000000           -0.237048
# under-five deaths                0.507809 -0.237048            1.000000
# Polio                           -0.136669  0.281260           -0.188864
# Total expenditure               -0.104133  0.230745           -0.127960
# Diphtheria                      -0.142385  0.280267           -0.195808
#  HIV/AIDS                        0.030899 -0.243383            0.038062
# GDP                             -0.069253  0.273932           -0.106093
# Population                       0.237188 -0.069667            0.539260
#  thinness  1-19 years            0.224870 -0.532487            0.466697
#  thinness 5-9 years              0.221138 -0.539365            0.471167
# Income composition of resources -0.111089  0.471947           -0.159264
# Schooling                       -0.120799  0.499806           -0.206242
#
#                                     Polio  Total expenditure  Diphtheria   \
# Life expectancy                  0.458399           0.208844     0.472211
# Adult Mortality                 -0.270002          -0.111796    -0.270301
# infant deaths                   -0.170896          -0.126268    -0.175376
# Alcohol                          0.211744           0.296153     0.212388
# percentage expenditure           0.146148           0.175559     0.142506
# Hepatitis B                      0.364890           0.055988     0.449151
# Measles                         -0.136669          -0.104133    -0.142385
#  BMI                             0.281260           0.230745     0.280267
# under-five deaths               -0.188864          -0.127960    -0.195808
# Polio                            1.000000           0.131037     0.673977
# Total expenditure                0.131037           1.000000     0.146485
# Diphtheria                       0.673977           0.146485     1.000000
#  HIV/AIDS                       -0.159128          -0.000289    -0.164419
# GDP                              0.189926           0.112099     0.181953
# Population                      -0.044813          -0.061602    -0.033128
#  thinness  1-19 years           -0.218401          -0.267572    -0.226409
#  thinness 5-9 years             -0.219168          -0.274069    -0.219699
# Income composition of resources  0.345172           0.154328     0.359379
# Schooling                        0.375830           0.220170     0.379062
#
#                                   HIV/AIDS       GDP  Population  \
# Life expectancy                  -0.556703  0.430461   -0.029014
# Adult Mortality                   0.523886 -0.281434   -0.005292
# infant deaths                     0.025231 -0.102829    0.551667
# Alcohol                          -0.046235  0.313060   -0.026836
# percentage expenditure           -0.097857  0.901819   -0.016888
# Hepatitis B                      -0.085497  0.076660   -0.125006
# Measles                           0.030899 -0.069253    0.237188
#  BMI                             -0.243383  0.273932   -0.069667
# under-five deaths                 0.038062 -0.106093    0.539260
# Polio                            -0.159128  0.189926   -0.044813
# Total expenditure                -0.000289  0.112099   -0.061602
# Diphtheria                       -0.164419  0.181953   -0.033128
#  HIV/AIDS                         1.000000 -0.122590   -0.017094
# GDP                              -0.122590  1.000000   -0.025269
# Population                       -0.017094 -0.025269    1.000000
#  thinness  1-19 years             0.203684 -0.263323    0.236410
#  thinness 5-9 years               0.206899 -0.266935    0.235278
# Income composition of resources  -0.247823  0.435960   -0.017237
# Schooling                        -0.218822  0.432229   -0.036814
#
#                                   thinness  1-19 years   thinness 5-9 years  \
# Life expectancy                              -0.468002            -0.462473
# Adult Mortality                               0.296135             0.301634
# infant deaths                                 0.464811             0.470445
# Alcohol                                      -0.413021            -0.402034
# percentage expenditure                       -0.249610            -0.251144
# Hepatitis B                                  -0.097576            -0.100576
# Measles                                       0.224870             0.221138
#  BMI                                         -0.532487            -0.539365
# under-five deaths                             0.466697             0.471167
# Polio                                        -0.218401            -0.219168
# Total expenditure                            -0.267572            -0.274069
# Diphtheria                                   -0.226409            -0.219699
#  HIV/AIDS                                     0.203684             0.206899
# GDP                                          -0.263323            -0.266935
# Population                                    0.236410             0.235278
#  thinness  1-19 years                         1.000000             0.939187
#  thinness 5-9 years                           0.939187             1.000000
# Income composition of resources              -0.401437            -0.390961
# Schooling                                    -0.437126            -0.426925
#
#                                  Income composition of resources  Schooling
# Life expectancy                                         0.688662   0.713054
# Adult Mortality                                        -0.436332  -0.433415
# infant deaths                                          -0.141571  -0.190951
# Alcohol                                                 0.418372   0.498899
# percentage expenditure                                  0.374730   0.386076
# Hepatitis B                                             0.117652   0.141275
# Measles                                                -0.111089  -0.120799
#  BMI                                                    0.471947   0.499806
# under-five deaths                                      -0.159264  -0.206242
# Polio                                                   0.345172   0.375830
# Total expenditure                                       0.154328   0.220170
# Diphtheria                                              0.359379   0.379062
#  HIV/AIDS                                              -0.247823  -0.218822
# GDP                                                     0.435960   0.432229
# Population                                             -0.017237  -0.036814
#  thinness  1-19 years                                  -0.401437  -0.437126
#  thinness 5-9 years                                    -0.390961  -0.426925
# Income composition of resources                         1.000000   0.795383
# Schooling                                               0.795383   1.000000

# %%
plt.matshow( le_corr )

# %%
f, ax = plt.subplots(figsize=(10, 8))

sns.heatmap(le_corr, mask=np.zeros_like(le_corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)
# Out:
# C:\Users\heber\AppData\Local\Temp/ipykernel_18588/3902061555.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   sns.heatmap(le_corr, mask=np.zeros_like(le_corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
# <AxesSubplot:>

# %% [markdown]
# ## Análisis de Frecuencias (Wendy)

# %%
vdf2=vdf1

# %% [markdown]
# Porcentaje de Mortalidad por año.

# %%
x=vdf2.loc[: ,['Country', 'Year']]

# %%
x['Porcentage Mortality']=(((vdf2['Population']/ 1000)*(vdf2['Adult Mortality']+ vdf2['infant deaths']+vdf2['under-five deaths ']))/ vdf2['Population'])*100

# %%
x
# Out:
#           Country  Year  Porcentage Mortality
# 0     Afghanistan  2015                  40.8
# 1     Afghanistan  2014                  42.1
# 2     Afghanistan  2013                  42.3
# 3     Afghanistan  2012                  43.4
# 4     Afghanistan  2011                  44.3
# ...           ...   ...                   ...
# 2933     Zimbabwe  2004                  79.2
# 2934     Zimbabwe  2003                  78.2
# 2935     Zimbabwe  2002                  13.8
# 2936     Zimbabwe  2001                  75.0
# 2937     Zimbabwe  2000                  72.8
#
# [2938 rows x 3 columns]

# %% [markdown]
# ¿Cuales son los 10 paises con menor Masa Muscular de los ultimos 5 años?

# %%
x= vdf2.loc[: , ['Country', 'Year', ' BMI ']]

# %%
x['orden ']=x.sort_values(['Country', 'Year'], ascending= False).groupby(['Country'])['Year'].rank(method= 'first', ascending = False)

# %%
 z = x.loc[x['orden ']<= 5 ,['Country', 'Year',' BMI '] ]

# %%
z =z.groupby('Country', as_index= False ).agg({' BMI ': ['max', 'min']})

# %%
z.columns= z.columns.droplevel(1)

# %%
z.columns=['Country', ' BMI Max ', ' BMI Min ']

# %%
z= z.loc[:,['Country', ' BMI Max ',' BMI Min ']].sort_values([' BMI Max '] )

# %%
z.head(10)
# Out:
#                    Country   BMI Max    BMI Min
# 142  Saint Kitts and Nevis        5.2        5.2
# 171            Timor-Leste       17.4       15.8
# 189               Viet Nam       17.5       14.7
# 57                Ethiopia       17.6       16.0
# 12              Bangladesh       18.3       15.8
# 179                 Uganda       18.5       16.7
# 55                 Eritrea       18.6       16.5
# 26                 Burundi       18.7       16.6
# 76                   India       18.7       16.4
# 0              Afghanistan       19.1       17.2

# %% [markdown]
# ¿Cuales son los 10 paises con mayor porcentaje de niños delgados entre 5 a 9 años ?

# %%
x= vdf2.loc[: , ['Country', 'Year', ' thinness 5-9 years']]

# %%
x['orden ']=x.sort_values(['Country', 'Year'], ascending= False).groupby(['Country'])['Year'].rank(method= 'first', ascending = False)

# %%
 z = x.loc[x['orden ']==1  ,['Country', 'Year',' thinness 5-9 years'] ]

# %%
z.loc[x['Country']=='Afghanistan', : ]
# Out:
#        Country  Year   thinness 5-9 years
# 0  Afghanistan  2015                 17.3

# %%
z =z.sort_values(' thinness 5-9 years', ascending= False)

# %%
z.head(10)
# Out:
#           Country  Year   thinness 5-9 years
# 1186        India  2015                 27.3
# 1942     Pakistan  2015                 19.6
# 192    Bangladesh  2015                 18.3
# 0     Afghanistan  2015                 17.3
# 1813        Nepal  2015                 16.1
# 288        Bhutan  2015                 16.0
# 2441    Sri Lanka  2015                 15.0
# 2874     Viet Nam  2015                 14.5
# 1602     Maldives  2015                 13.6
# 2890        Yemen  2015                 13.4

# %% [markdown]
# ¿Cuales son los 10 paises con mayor porcentaje de niños delgados entre 10 a 19 años ?

# %%
x= vdf2.loc[: , ['Country', 'Year', ' thinness  1-19 years']]

# %%
x['orden ']=x.sort_values(['Country', 'Year'], ascending= False).groupby(['Country'])['Year'].rank(method= 'first', ascending = False)

# %%
z = x.loc[x['orden ']==1  ,['Country', 'Year',' thinness  1-19 years'] ]

# %%
z =z.sort_values(' thinness  1-19 years', ascending= False)

# %%
z.head(10)
# Out:
#           Country  Year   thinness  1-19 years
# 1186        India  2015                   26.7
# 1942     Pakistan  2015                   19.2
# 192    Bangladesh  2015                   17.9
# 0     Afghanistan  2015                   17.2
# 1813        Nepal  2015                   15.7
# 288        Bhutan  2015                   15.4
# 2441    Sri Lanka  2015                   15.1
# 2874     Viet Nam  2015                   14.2
# 2890        Yemen  2015                   13.6
# 1602     Maldives  2015                   13.6

# %%
vdf2.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %% [markdown]
# ¿Cuales son los 10 paises que tienen el mayor porcentaje en las vacunas de Hepatitis B, Polio y Difteria ?

# %%
x= vdf2.loc[:, ['Country', 'Year','Hepatitis B','Polio', 'Diphtheria ' ]]

# %%
x['orden ']=x.sort_values(['Country', 'Year'], ascending= False).groupby(['Country'])['Year'].rank(method= 'first', ascending = False)

# %%
z = x.loc[x['orden ']==1  ,['Country', 'Year','Hepatitis B','Polio', 'Diphtheria '] ]

# %%
z
# Out:
#                                  Country  Year  Hepatitis B  Polio  \
# 0                            Afghanistan  2015         65.0    6.0
# 16                               Albania  2015         99.0   99.0
# 32                               Algeria  2015         95.0   95.0
# 48                                Angola  2015         64.0    7.0
# 64                   Antigua and Barbuda  2015         99.0   86.0
# ...                                  ...   ...          ...    ...
# 2858  Venezuela (Bolivarian Republic of)  2015         87.0   87.0
# 2874                            Viet Nam  2015         97.0   97.0
# 2890                               Yemen  2015         69.0   63.0
# 2906                              Zambia  2015          9.0    9.0
# 2922                            Zimbabwe  2015         87.0   88.0
#
#       Diphtheria
# 0            65.0
# 16           99.0
# 32           95.0
# 48           64.0
# 64           99.0
# ...           ...
# 2858         87.0
# 2874         97.0
# 2890         69.0
# 2906          9.0
# 2922         87.0
#
# [193 rows x 5 columns]

# %%
z.loc[z['Country']=='Afghanistan',:]
# Out:
#        Country  Year  Hepatitis B  Polio  Diphtheria
# 0  Afghanistan  2015         65.0    6.0         65.0

# %%
mejor= z.sort_values(['Hepatitis B','Polio', 'Diphtheria '], ascending= False )

# %%
mejor.head(10)
# Out:
#                                Country  Year  Hepatitis B  Polio  Diphtheria
# 16                             Albania  2015         99.0   99.0         99.0
# 224                            Belarus  2015         99.0   99.0         99.0
# 304   Bolivia (Plurinational State of)  2015         99.0   99.0         99.0
# 368                  Brunei Darussalam  2015         99.0   99.0         99.0
# 560                              China  2015         99.0   99.0         99.0
# 657                               Cuba  2015         99.0   99.0         99.0
# 898                               Fiji  2015         99.0   99.0         99.0
# 1330                            Jordan  2015         99.0   99.0         99.0
# 1394                            Kuwait  2015         99.0   99.0         99.0
# 1586                          Malaysia  2015         99.0   99.0         99.0

# %%
peor = z.sort_values(['Hepatitis B', 'Diphtheria ','Polio'] )

# %% [markdown]
# ¿Cuales son los 5 paises que tienen el porcentaje mas bajo de vacuna para el Polio en niños de 1 año?

# %%
x=peor.loc[:, ['Country','Polio']].sort_values(['Polio'])

# %%
x.head(5)
# Out:
#                    Country  Polio
# 2537  Syrian Arab Republic    5.0
# 0              Afghanistan    6.0
# 48                  Angola    7.0
# 1764            Mozambique    8.0
# 2633                 Tonga    8.0

# %% [markdown]
# ¿Cuales son los 5 paises que tienen el porcentaje mas bajo de vacuna para el Hepatitis B en niños de 1 año?

# %%
y =peor.loc[:, ['Country','Hepatitis B']].sort_values(['Hepatitis B'])

# %%
y.head(5)
# Out:
#           Country  Hepatitis B
# 1122        Haiti          6.0
# 2023  Philippines          6.0
# 608         Congo          8.0
# 1764   Mozambique          8.0
# 946         Gabon          8.0

# %% [markdown]
# ¿Cuales son los 5 paises que tienen el porcentaje mas bajo de vacuna para el Difteria en niños de 1 año?

# %%
z=peor.loc[:, ['Country','Diphtheria ']].sort_values(['Diphtheria '])

# %%
z.head(5)
# Out:
#           Country  Diphtheria
# 1122        Haiti          6.0
# 2023  Philippines          6.0
# 608         Congo          8.0
# 1764   Mozambique          8.0
# 946         Gabon          8.0

# %% [markdown]
# ## PCA (Rovin)

# %% [markdown]
# ## Verificamos si existe multicolinealiadad entre algunas columnas

# %%
vdf4 = vdf1

# %%
def print_scatter(vdf4, x_label, y_label):
    N = 2938
    x = vdf4[x_label]
    y = vdf4[y_label]
    colors = np.random.rand(N)

    plt.scatter(x, y, c=colors, alpha=0.9)
    plt.show()

# %%
print_scatter(vdf4, " thinness  1-19 years"," thinness 5-9 years")

# %%
print_scatter(vdf4, "under-five deaths ","infant deaths")

# %% [markdown]
# #### Vemos que entre estas columnas hay una multicolinealidad alta entre ellas por lo tanto excluimos una de del analisis PCA
# #### Usamos solo las columnas numericas continuas

# %%
columnas_a_usar1 = ['Life expectancy ', 'Adult Mortality',
       'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
       'Measles ', ' BMI ','Polio', 'Total expenditure',
       'Diphtheria ', ' HIV/AIDS', 'GDP',' thinness  1-19 years',
        'Income composition of resources', 'Schooling']

# %%
vdf_pca  = vdf4.loc[ : , columnas_a_usar1 ].values

# %% [markdown]
# #### Estandarizamos los valores

# %%
StandardScaler().fit_transform(vdf_pca)
# Out:
# array([[-0.44540826,  0.79211913,  0.26882378, ...,  2.815209  ,
#         -0.73797341, -0.58501698],
#        [-0.98182707,  0.85660141,  0.28578638, ...,  2.88343932,
#         -0.75260009, -0.61564876],
#        [-0.98182707,  0.83242056,  0.30274898, ...,  2.9289262 ,
#         -0.78185344, -0.64628054],
#        ...,
#        [-2.57004747, -0.73933497, -0.04498439, ..., -0.82374138,
#         -0.99150247, -0.61564876],
#        [-2.51745739,  4.20161958, -0.04498439, ..., -0.73276762,
#         -0.99150247, -0.67691233],
#        [-2.44383128,  4.0323536 , -0.05346569, ...,  1.40511573,
#         -0.95737356, -0.67691233]])

# %% [markdown]
# #### Aplicamos el algoritmo de reduccion PCA a dos dimensiones

# %%
pca = PCA(n_components=2)

# %% [markdown]
# #### Hacemos una tranformacion a los dos componentes principales

# %%
componentesPrincipales = pca.fit_transform(vdf_pca)

# %%
componentesPrincipales
# Out:
# array([[-5674.08408036, -2481.93224727],
#        [-5510.42300775, -3124.00684532],
#        [-5479.26329109, -3180.81710632],
#        ...,
#        [-6019.55556292, -3423.03522927],
#        [-5590.82410762, -3103.2846303 ],
#        [-5787.64946507, -2169.83095876]])

# %%
print(vdf_pca.shape)
print(componentesPrincipales.shape)
# Out:
# (2938, 16)
# (2938, 2)

# %%
pcadf = pd.DataFrame(data=componentesPrincipales , columns=['c1','c2'])

# %%
print_scatter(pcadf, 'c1', 'c2')

# %% [markdown]
# ## Clústeres (Heber)

# %%
vdf3= vdf1

# %% [markdown]
# ### DEJAMOS SOLO LAS COLUMNAS QUE NO PRESENTAN UNA ALTA CORRELACION ENTRE ELLAS COMO SER UNDER-FIVE-DEATHS CON INFANT-DEATHS

# %%
columnas_a_usar = [ 'Life expectancy ', 'Adult Mortality',
       'infant deaths', 'Alcohol', 'Hepatitis B',
       'Measles ', ' BMI ', 'Polio', 'Total expenditure',
       'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
       ' thinness  1-19 years', 'Schooling']

# %%
vdfx  = vdf3.loc[ : , columnas_a_usar].values

# %% [markdown]
# ### Estandarizamos los valores

# %%
StandardScaler().fit_transform(vdfx)
# Out:
# array([[-0.44540826,  0.79211913,  0.26882378, ...,  0.43518312,
#          2.815209  , -0.58501698],
#        [-0.98182707,  0.85660141,  0.28578638, ..., -0.18334898,
#          2.88343932, -0.61564876],
#        [-0.98182707,  0.83242056,  0.30274898, ...,  0.39806617,
#          2.9289262 , -0.64628054],
#        ...,
#        [-2.57004747, -0.73933497, -0.04498439, ..., -0.18708986,
#         -0.82374138, -0.61564876],
#        [-2.51745739,  4.20161958, -0.04498439, ...,  0.03953317,
#         -0.73276762, -0.67691233],
#        [-2.44383128,  4.0323536 , -0.05346569, ...,  0.03686875,
#          1.40511573, -0.67691233]])

# %% [markdown]
# ### Reducimos a dos componentes haciendo uso de PCA con el objetivo de que se concentre la informacion en las dos primeras componentes

# %%
pcavdf3 = PCA(n_components=2)

# %%
componentes_principales = pcavdf3.fit_transform(vdfx)

# %%
pcadfv = pd.DataFrame(data=componentes_principales , columns=['c1','c2'])

# %%
kmeans = KMeans(n_clusters=2).fit(pcadfv)

# %%
centroids = kmeans.cluster_centers_
centroids
# Out:
# array([[ 1.17092369e+09,  2.33053386e+03],
#        [-1.99611949e+06, -3.97295237e+00]])

# %%
plt.scatter(pcadfv['c1'], pcadfv['c2'], c= kmeans.labels_.astype(float), s=50, alpha=0.5)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)
plt.show()

# %%
final_vdf = vdf3.loc[ : , columnas_a_usar ]

# %%
final_vdf["cluster"] = kmeans.labels_
final_vdf.cluster = final_vdf.cluster.astype(str)

# %%
final_vdf
# Out:
#       Life expectancy   Adult Mortality  infant deaths  Alcohol  Hepatitis B  \
# 0                 65.0            263.0             62     0.01         65.0
# 1                 59.9            271.0             64     0.01         62.0
# 2                 59.9            268.0             66     0.01         64.0
# 3                 59.5            272.0             69     0.01         67.0
# 4                 59.2            275.0             71     0.01         68.0
# ...                ...              ...            ...      ...          ...
# 2933              44.3            723.0             27     4.36         68.0
# 2934              44.5            715.0             26     4.06          7.0
# 2935              44.8             73.0             25     4.43         73.0
# 2936              45.3            686.0             25     1.72         76.0
# 2937              46.0            665.0             24     1.68         79.0
#
#       Measles    BMI   Polio  Total expenditure  Diphtheria    HIV/AIDS  \
# 0         1154   19.1    6.0               8.16         65.0        0.1
# 1          492   18.6   58.0               8.18         62.0        0.1
# 2          430   18.1   62.0               8.13         64.0        0.1
# 3         2787   17.6   67.0               8.52         67.0        0.1
# 4         3013   17.2   68.0               7.87         68.0        0.1
# ...        ...    ...    ...                ...          ...        ...
# 2933        31   27.1   67.0               7.13         65.0       33.6
# 2934       998   26.7    7.0               6.52         68.0       36.7
# 2935       304   26.3   73.0               6.53         71.0       39.8
# 2936       529   25.9   76.0               6.16         75.0       42.1
# 2937      1483   25.5   78.0               7.10         78.0       43.5
#
#              GDP  Population   thinness  1-19 years  Schooling cluster
# 0     584.259210  33736494.0                   17.2       10.1       1
# 1     612.696514    327582.0                   17.5       10.0       1
# 2     631.744976  31731688.0                   17.7        9.9       1
# 3     669.959000   3696958.0                   17.9        9.8       1
# 4      63.537231   2978599.0                   18.2        9.5       1
# ...          ...         ...                    ...        ...     ...
# 2933  454.366654  12777511.0                    9.4        9.2       1
# 2934  453.351155  12633897.0                    9.8        9.5       1
# 2935   57.348340    125525.0                    1.2       10.0       1
# 2936  548.587312  12366165.0                    1.6        9.8       1
# 2937  547.358878  12222251.0                   11.0        9.8       1
#
# [2938 rows x 16 columns]

# %%
loadings = pcavdf3.components_.T * np.sqrt(pcavdf3.explained_variance_)

# %%
fig = px.scatter(componentes_principales, x=0, y=1, color=final_vdf['cluster'])

# %%
for i, feature in enumerate(columnas_a_usar):
    fig.add_shape(
        type='line',
        x0=0, y0=0,
        x1=loadings[i, 0],
        y1=loadings[i, 1]
    )
    fig.add_annotation(
        x=loadings[i, 0],
        y=loadings[i, 1],
        ax=0, ay=0,
        xanchor="center",
        yanchor="bottom",
        text=feature,
    )
fig.show()

# %%
final_vdf_cluster_0 = final_vdf.loc[ final_vdf['cluster'] == '0'  , : ]
final_vdf_cluster_1 = final_vdf.loc[ final_vdf['cluster'] == '1'  , : ]

# %%
final_vdf_cluster_0.describe()
# Out:
#        Life expectancy   Adult Mortality  infant deaths   Alcohol  \
# count          5.000000         5.000000       5.000000  5.000000
# mean          65.280000       132.600000    1391.400000  1.700000
# std            1.584929        97.107157     252.922518  0.779872
# min           64.000000        26.000000     957.000000  1.200000
# 25%           64.400000        28.000000    1400.000000  1.270000
# 50%           64.800000       184.000000    1500.000000  1.370000
# 75%           65.200000       211.000000    1500.000000  1.590000
# max           68.000000       214.000000    1600.000000  3.070000
#
#        Hepatitis B      Measles        BMI       Polio  Total expenditure  \
# count     5.000000      5.000000   5.000000   5.000000           5.000000
# mean     21.000000  55409.200000  14.580000  68.000000           4.334000
# std      32.434549  17417.953933   2.033962   9.617692           0.200325
# min       6.000000  36711.000000  13.000000  58.000000           4.220000
# 25%       6.000000  41144.000000  13.500000  65.000000           4.230000
# 50%       6.000000  55443.000000  13.900000  66.000000           4.250000
# 75%       8.000000  64185.000000  14.400000  67.000000           4.280000
# max      79.000000  79563.000000  18.100000  84.000000           4.690000
#
#        Diphtheria    HIV/AIDS          GDP    Population  \
# count     5.000000   5.000000     5.000000  5.000000e+00
# mean     68.400000   0.280000   636.536468  1.181155e+09
# std       9.316652   0.044721   608.798142  6.608896e+07
# min      63.000000   0.200000    77.819000  1.126136e+09
# 25%      64.000000   0.300000   118.166373  1.144119e+09
# 50%      65.000000   0.300000   621.318377  1.161978e+09
# 75%      65.000000   0.300000   792.259698  1.179681e+09
# max      85.000000   0.300000  1573.118890  1.293859e+09
#
#         thinness  1-19 years  Schooling
# count               5.000000    5.00000
# mean               27.080000    9.96000
# std                 0.164317    0.95551
# min                26.800000    9.20000
# 25%                27.100000    9.40000
# 50%                27.100000    9.70000
# 75%                27.200000    9.90000
# max                27.200000   11.60000

# %%
final_vdf_cluster_1.describe()
# Out:
#        Life expectancy   Adult Mortality  infant deaths      Alcohol  \
# count       2933.000000      2933.000000    2933.000000  2933.000000
# mean          69.241459       164.780430      27.983635     4.551729
# std            9.515636       124.133068     103.336688     3.923419
# min           36.300000         1.000000       0.000000     0.010000
# 25%           63.100000        74.000000       0.000000     1.080000
# 50%           72.100000       144.000000       3.000000     3.755000
# 75%           75.600000       227.000000      22.000000     7.400000
# max           89.000000       723.000000    1800.000000    17.870000
#
#        Hepatitis B       Measles          BMI         Polio  \
# count  2933.000000    2933.000000  2933.000000  2933.000000
# mean     83.127855    2329.258779    38.421752    82.642687
# std      22.841997   11247.762441    19.927959    23.376577
# min       1.000000       0.000000     1.000000     3.000000
# 25%      82.000000       0.000000    19.500000    78.000000
# 50%      92.000000      16.000000    43.500000    93.000000
# 75%      96.000000     353.000000    56.100000    97.000000
# max      99.000000  212183.000000    87.300000    99.000000
#
#        Total expenditure  Diphtheria      HIV/AIDS            GDP  \
# count        2933.000000  2933.000000  2933.000000    2933.000000
# mean            5.926809    82.416979     1.744596    6621.709658
# std             2.401906    23.666157     5.081753   13305.625623
# min             0.370000     2.000000     0.100000       1.681350
# 25%             4.380000    78.000000     0.100000     582.775532
# 50%             5.755000    93.000000     0.100000    1766.947595
# 75%             7.340000    97.000000     0.800000    4787.699532
# max            17.600000    99.000000    50.600000  119172.741800
#
#          Population   thinness  1-19 years    Schooling
# count  2.933000e+03            2933.000000  2933.000000
# mean   8.234732e+06               4.783941    12.013331
# std    2.398652e+07               4.304151     3.266633
# min    3.400000e+01               0.100000     0.000000
# 25%    4.162680e+05               1.600000    10.300000
# 50%    1.386542e+06               3.300000    12.300000
# 75%    4.564297e+06               7.100000    14.100000
# max    2.581621e+08              27.700000    20.700000

# %% [markdown]
# ## Eigen Vectors, Kmean (Daniel)

# %% [markdown]
# ## Regresiones Lineales y Múltiples
